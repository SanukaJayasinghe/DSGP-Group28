# %% [markdown]
# # import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mediapipe as mp
import cv2
import os

# %% [markdown]
# # initialize media pipe

# %%
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose = mp_pose.Pose(min_detection_confidence=0.6,
                    min_tracking_confidence=0.6,
                    static_image_mode=False,
                    smooth_landmarks=True,
                    model_complexity=2)

# %%
desired_width = 480
desired_height = 360

# %% [markdown]
# # function to calculate angles

# %%
def calculate_angle(row):
    import math
    row = abs(row)

    # Accessing columns by their index positions (0 to 5) from the row
    radians = math.atan2(row[5] - row[3], row[4] - row[2]) - math.atan2(row[1] - row[3], row[0] - row[2])
    angle = math.degrees(radians)
    if angle < 0:
        angle += 360
    return angle

# %% [markdown]
# # processing video and extracting angles function

# %%
def processVideo(VideoFile, positive=True):
    cap = cv2.VideoCapture(VideoFile)

    data_dict = {}

    for landmark in mp_pose.PoseLandmark:
        x_list_name = f"{landmark.name}_Point_x"
        y_list_name = f"{landmark.name}_Point_y"
        z_list_name = f"{landmark.name}_Point_z"
        visibility_list_name = f"{landmark.name}_visibility"

        data_dict[x_list_name] = []
        data_dict[y_list_name] = []
        data_dict[z_list_name] = []
        data_dict[visibility_list_name] = []

    while cap.isOpened():
        success, image = cap.read()
        if not success:
            break

        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        results = pose.process(image_rgb)

        if results.pose_landmarks:

            for landmark in mp_pose.PoseLandmark:
                x_list_name = f"{landmark.name}_Point_x"
                y_list_name = f"{landmark.name}_Point_y"
                z_list_name = f"{landmark.name}_Point_z"
                visibility_list_name = f"{landmark.name}_visibility"

                data_dict[x_list_name].append(results.pose_landmarks.landmark[landmark].x)
                data_dict[y_list_name].append(results.pose_landmarks.landmark[landmark].y)
                data_dict[z_list_name].append(results.pose_landmarks.landmark[landmark].z)
                data_dict[visibility_list_name].append(results.pose_landmarks.landmark[landmark].visibility)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

    df = pd.DataFrame(data_dict)
    Angles_df = pd.DataFrame()

    ####################Angles
    ##########################################SHOULDER

    # LEFT_SHOULDER
    left_shoulder = df[[
        'LEFT_ELBOW_Point_x', 'LEFT_ELBOW_Point_y',
        'LEFT_SHOULDER_Point_x', 'LEFT_SHOULDER_Point_y',
        'LEFT_HIP_Point_x', 'LEFT_HIP_Point_y'
    ]]
    Angles_df['Left_Shoulder_Angle'] = left_shoulder.apply(calculate_angle, axis=1)

    # RIGHT_SHOULDER
    right_shoulder = df[[
        'RIGHT_ELBOW_Point_x', 'RIGHT_ELBOW_Point_y',
        'RIGHT_SHOULDER_Point_x', 'RIGHT_SHOULDER_Point_y',
        'RIGHT_HIP_Point_x', 'RIGHT_HIP_Point_y'
    ]]
    Angles_df['Right_Shoulder_Angle'] = right_shoulder.apply(calculate_angle, axis=1)

    ###########################################ELBOW

    # LEFT_ELBOW
    left_elbow = df[[
        'LEFT_WRIST_Point_x', 'LEFT_WRIST_Point_y',
        'LEFT_ELBOW_Point_x', 'LEFT_ELBOW_Point_y',
        'LEFT_SHOULDER_Point_x', 'LEFT_SHOULDER_Point_y'
    ]]
    Angles_df['Left_Elbow_Angle'] = left_elbow.apply(calculate_angle, axis=1)

    # RIGHT_ELBOW
    right_elbow = df[[
        'RIGHT_WRIST_Point_x', 'RIGHT_WRIST_Point_y',
        'RIGHT_ELBOW_Point_x', 'RIGHT_ELBOW_Point_y',
        'RIGHT_SHOULDER_Point_x', 'RIGHT_SHOULDER_Point_y'
    ]]
    Angles_df['Right_Elbow_Angle'] = right_elbow.apply(calculate_angle, axis=1)

    #############################################WRIST

    # LEFT_WRIST
    left_wrist = df[[
        'LEFT_ELBOW_Point_x', 'LEFT_ELBOW_Point_y',
        'LEFT_WRIST_Point_x', 'LEFT_WRIST_Point_y',
        'LEFT_SHOULDER_Point_x', 'LEFT_SHOULDER_Point_y'
    ]]
    Angles_df['Left_Wrist_Angle'] = left_wrist.apply(calculate_angle, axis=1)

    # RIGHT_WRIST
    right_wrist = df[[
        'RIGHT_ELBOW_Point_x', 'RIGHT_ELBOW_Point_y',
        'RIGHT_WRIST_Point_x', 'RIGHT_WRIST_Point_y',
        'RIGHT_SHOULDER_Point_x', 'RIGHT_SHOULDER_Point_y'
    ]]
    Angles_df['Right_Wrist_Angle'] = right_wrist.apply(calculate_angle, axis=1)

    ##############################################HIP

    # LEFT_HIP
    left_hip = df[[
        'LEFT_SHOULDER_Point_x', 'LEFT_SHOULDER_Point_y',
        'LEFT_HIP_Point_x', 'LEFT_HIP_Point_y',
        'LEFT_KNEE_Point_x', 'LEFT_KNEE_Point_y'
    ]]
    Angles_df['Left_Hip_Angle'] = left_hip.apply(calculate_angle, axis=1)

    # RIGHT_HIP
    right_hip = df[[
        'RIGHT_SHOULDER_Point_x', 'RIGHT_SHOULDER_Point_y',
        'RIGHT_HIP_Point_x', 'RIGHT_HIP_Point_y',
        'RIGHT_KNEE_Point_x', 'RIGHT_KNEE_Point_y'
    ]]
    Angles_df['Right_Hip_Angle'] = right_hip.apply(calculate_angle, axis=1)

    ##############################################KNEE

    # LEFT_KNEE
    left_knee = df[[
        'LEFT_HIP_Point_x', 'LEFT_HIP_Point_y',
        'LEFT_KNEE_Point_x', 'LEFT_KNEE_Point_y',
        'LEFT_ANKLE_Point_x', 'LEFT_ANKLE_Point_y'
    ]]
    Angles_df['Left_Knee_Angle'] = left_knee.apply(calculate_angle, axis=1)

    #RIGHT_KNEE

    Right_Knee = df[[
        'RIGHT_HIP_Point_x', 'RIGHT_HIP_Point_y',
        'RIGHT_KNEE_Point_x', 'RIGHT_KNEE_Point_y',
        'RIGHT_ANKLE_Point_x', 'RIGHT_ANKLE_Point_y'
    ]]
    Angles_df['Right_Knee_Angle'] = Right_Knee.apply(calculate_angle, axis=1)

    ###################################################NECK
    Neck = df[[
        'LEFT_SHOULDER_Point_x', 'LEFT_SHOULDER_Point_y',
        'NOSE_Point_x', 'NOSE_Point_y',
        'RIGHT_SHOULDER_Point_x', 'RIGHT_SHOULDER_Point_y'
    ]]
    Angles_df['Neck_Angle'] = Neck.apply(calculate_angle, axis=1)

    ###############################################ANKLE

    #LEFT_ANKLE
    Left_Ankle = df[[
        'LEFT_KNEE_Point_x', 'LEFT_KNEE_Point_y',
        'LEFT_ANKLE_Point_x', 'LEFT_ANKLE_Point_y',
        'LEFT_HEEL_Point_x', 'LEFT_HEEL_Point_y'
    ]]
    Angles_df['Left_Ankle_Angle'] = Left_Ankle.apply(calculate_angle, axis=1)

    #RIGHT_ANKLE

    Right_Ankle = df[[
        'RIGHT_KNEE_Point_x', 'RIGHT_KNEE_Point_y',
        'RIGHT_ANKLE_Point_x', 'RIGHT_ANKLE_Point_y',
        'RIGHT_HEEL_Point_x', 'RIGHT_HEEL_Point_y'
    ]]
    Angles_df['Right_Ankle_Angle'] = Right_Ankle.apply(calculate_angle, axis=1)

    ################################################HEEL

    #LEFT_HEEL

    Left_Heel = df[[
        'LEFT_ANKLE_Point_x', 'LEFT_ANKLE_Point_y',
        'LEFT_HEEL_Point_x', 'LEFT_HEEL_Point_y',
        'LEFT_FOOT_INDEX_Point_x', 'LEFT_FOOT_INDEX_Point_y'
    ]]
    Angles_df['Left_Heel_Angle'] = Left_Heel.apply(calculate_angle, axis=1)

    #RIGHT_HEEL

    Right_Heel = df[[
        'RIGHT_ANKLE_Point_x', 'RIGHT_ANKLE_Point_y',
        'RIGHT_HEEL_Point_x', 'RIGHT_HEEL_Point_y',
        'RIGHT_FOOT_INDEX_Point_x', 'RIGHT_FOOT_INDEX_Point_y'
    ]]
    Angles_df['Right_Heel_Angle'] = Right_Heel.apply(calculate_angle, axis=1)

    ################################################FOOT_INDEX

    #LEFT_FOOT_INDEX

    Left_Foot_Index = df[[
        'LEFT_ANKLE_Point_x', 'LEFT_ANKLE_Point_y',
        'LEFT_FOOT_INDEX_Point_x', 'LEFT_FOOT_INDEX_Point_y',
        'LEFT_HEEL_Point_x', 'LEFT_HEEL_Point_y'
    ]]
    Angles_df['Left_Foot_Index_Angle'] = Left_Foot_Index.apply(calculate_angle, axis=1)

    #RIGHT_FOOT_INDEX
    Right_Foot_Index = df[[
        'RIGHT_ANKLE_Point_x', 'RIGHT_ANKLE_Point_y',
        'RIGHT_FOOT_INDEX_Point_x', 'RIGHT_FOOT_INDEX_Point_y',
        'RIGHT_HEEL_Point_x', 'RIGHT_HEEL_Point_y'
    ]]
    Angles_df['Right_Foot_Index_Angle'] = Right_Foot_Index.apply(calculate_angle, axis=1)

    label = 1 if positive else 0

    return Angles_df.assign(Label=label)

# %%
frame_count = 0
frame_numbers = []

# %% [markdown]
# # feeding video to process video function

# %%
dataset = pd.DataFrame()

NegVideoFiles = os.listdir('Videos/Wrong sequence')
PosVideoFiles = os.listdir('Videos/Correct sequence')

# extracting angles from correct videos
for VideoFile in PosVideoFiles:
    label = True
    print(f'File in process : {VideoFile} \nLabel: {label}')

    angles_dataset = processVideo(f'Videos/Correct Sequence/{VideoFile}', positive=label)
    dataset = pd.concat([dataset, angles_dataset], ignore_index=True)
    print(dataset.info())

# extracting angles from wrong videos
for VideoFile in NegVideoFiles:
    label = False
    print(f'File in process : {VideoFile} \nLabel: {label}')

    angles_dataset = processVideo(f'Videos/Wrong Sequence/{VideoFile}', positive=label)
    dataset = pd.concat([dataset, angles_dataset], ignore_index=True)
    print(dataset.info())


# VideoFiles.remove('WPushUp2.mp4')
# for VideoFile in VideoFiles:
#     label = False if VideoFile.startswith('W') else True
#     print(f'File in process : {VideoFile}')
# 
#     angles_dataset = processVideo(f'Videos/{VideoFile}', positive=label)
#     dataset = pd.concat([dataset, angles_dataset], ignore_index=True)
#     print(dataset.info())

#save data set to csv
dataset.to_csv('Datasets/label.csv', index=False)
print(f"Data saved to Datasets/label.csv")
# Out:
# File in process : Copy of push up 1.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     61 non-null     float64
#  1   Right_Shoulder_Angle    61 non-null     float64
#  2   Left_Elbow_Angle        61 non-null     float64
#  3   Right_Elbow_Angle       61 non-null     float64
#  4   Left_Wrist_Angle        61 non-null     float64
#  5   Right_Wrist_Angle       61 non-null     float64
#  6   Left_Hip_Angle          61 non-null     float64
#  7   Right_Hip_Angle         61 non-null     float64
#  8   Left_Knee_Angle         61 non-null     float64
#  9   Right_Knee_Angle        61 non-null     float64
#  10  Neck_Angle              61 non-null     float64
#  11  Left_Ankle_Angle        61 non-null     float64
#  12  Right_Ankle_Angle       61 non-null     float64
#  13  Left_Heel_Angle         61 non-null     float64
#  14  Right_Heel_Angle        61 non-null     float64
#  15  Left_Foot_Index_Angle   61 non-null     float64
#  16  Right_Foot_Index_Angle  61 non-null     float64
#  17  Label                   61 non-null     int64
# dtypes: float64(17), int64(1)
# memory usage: 8.7 KB
# None
# File in process : Copy of push up 100.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     185 non-null    float64
#  1   Right_Shoulder_Angle    185 non-null    float64
#  2   Left_Elbow_Angle        185 non-null    float64
#  3   Right_Elbow_Angle       185 non-null    float64
#  4   Left_Wrist_Angle        185 non-null    float64
#  5   Right_Wrist_Angle       185 non-null    float64
#  6   Left_Hip_Angle          185 non-null    float64
#  7   Right_Hip_Angle         185 non-null    float64
#  8   Left_Knee_Angle         185 non-null    float64
#  9   Right_Knee_Angle        185 non-null    float64
#  10  Neck_Angle              185 non-null    float64
#  11  Left_Ankle_Angle        185 non-null    float64
#  12  Right_Ankle_Angle       185 non-null    float64
#  13  Left_Heel_Angle         185 non-null    float64
#  14  Right_Heel_Angle        185 non-null    float64
#  15  Left_Foot_Index_Angle   185 non-null    float64
#  16  Right_Foot_Index_Angle  185 non-null    float64
#  17  Label                   185 non-null    int64
# dtypes: float64(17), int64(1)
# memory usage: 26.1 KB
# None
# File in process : Copy of push up 101.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     262 non-null    float64
#  1   Right_Shoulder_Angle    262 non-null    float64
#  2   Left_Elbow_Angle        262 non-null    float64
#  3   Right_Elbow_Angle       262 non-null    float64
#  4   Left_Wrist_Angle        262 non-null    float64
#  5   Right_Wrist_Angle       262 non-null    float64
#  6   Left_Hip_Angle          262 non-null    float64
#  7   Right_Hip_Angle         262 non-null    float64
#  8   Left_Knee_Angle         262 non-null    float64
#  9   Right_Knee_Angle        262 non-null    float64
#  10  Neck_Angle              262 non-null    float64
#  11  Left_Ankle_Angle        262 non-null    float64
#  12  Right_Ankle_Angle       262 non-null    float64
#  13  Left_Heel_Angle         262 non-null    float64
#  14  Right_Heel_Angle        262 non-null    float64
#  15  Left_Foot_Index_Angle   262 non-null    float64
#  16  Right_Foot_Index_Angle  262 non-null    float64
#  17  Label                   262 non-null    int64
# dtypes: float64(17), int64(1)
# memory usage: 37.0 KB
# None
# File in process : Copy of push up 102.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345 entries, 0 to 344
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     345 non-null    float64
#  1   Right_Shoulder_Angle    345 non-null    float64
#  2   Left_Elbow_Angle        345 non-null    float64
#  3   Right_Elbow_Angle       345 non-null    float64
#  4   Left_Wrist_Angle        345 non-null    float64
#  5   Right_Wrist_Angle       345 non-null    float64
#  6   Left_Hip_Angle          345 non-null    float64
#  7   Right_Hip_Angle         345 non-null    float64
#  8   Left_Knee_Angle         345 non-null    float64
#  9   Right_Knee_Angle        345 non-null    float64
#  10  Neck_Angle              345 non-null    float64
#  11  Left_Ankle_Angle        345 non-null    float64
#  12  Right_Ankle_Angle       345 non-null    float64
#  13  Left_Heel_Angle         345 non-null    float64
#  14  Right_Heel_Angle        345 non-null    float64
#  15  Left_Foot_Index_Angle   345 non-null    float64
#  16  Right_Foot_Index_Angle  345 non-null    float64
#  17  Label                   345 non-null    int64
# dtypes: float64(17), int64(1)
# memory usage: 48.6 KB
# None
# File in process : Copy of push up 113.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     422 non-null    float64
#  1   Right_Shoulder_Angle    422 non-null    float64
#  2   Left_Elbow_Angle        422 non-null    float64
#  3   Right_Elbow_Angle       422 non-null    float64
#  4   Left_Wrist_Angle        422 non-null    float64
#  5   Right_Wrist_Angle       422 non-null    float64
#  6   Left_Hip_Angle          422 non-null    float64
#  7   Right_Hip_Angle         422 non-null    float64
#  8   Left_Knee_Angle         422 non-null    float64
#  9   Right_Knee_Angle        422 non-null    float64
#  10  Neck_Angle              422 non-null    float64
#  11  Left_Ankle_Angle        422 non-null    float64
#  12  Right_Ankle_Angle       422 non-null    float64
#  13  Left_Heel_Angle         422 non-null    float64
#  14  Right_Heel_Angle        422 non-null    float64
#  15  Left_Foot_Index_Angle   422 non-null    float64
#  16  Right_Foot_Index_Angle  422 non-null    float64
#  17  Label                   422 non-null    int64
# dtypes: float64(17), int64(1)
# memory usage: 59.5 KB
# None
# File in process : Copy of push up 114.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     510 non-null    float64
#  1   Right_Shoulder_Angle    510 non-null    float64
#  2   Left_Elbow_Angle        510 non-null    float64
#  3   Right_Elbow_Angle       510 non-null    float64
#  4   Left_Wrist_Angle        510 non-null    float64
#  5   Right_Wrist_Angle       510 non-null    float64
#  6   Left_Hip_Angle          510 non-null    float64
#  7   Right_Hip_Angle         510 non-null    float64
#  8   Left_Knee_Angle         510 non-null    float64
#  9   Right_Knee_Angle        510 non-null    float64
#  10  Neck_Angle              510 non-null    float64
#  11  Left_Ankle_Angle        510 non-null    float64
#  12  Right_Ankle_Angle       510 non-null    float64
#  13  Left_Heel_Angle         510 non-null    float64
#  14  Right_Heel_Angle        510 non-null    float64
#  15  Left_Foot_Index_Angle   510 non-null    float64
#  16  Right_Foot_Index_Angle  510 non-null    float64
#  17  Label                   510 non-null    int64
# dtypes: float64(17), int64(1)
# memory usage: 71.8 KB
# None
# File in process : Copy of push up 115.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 647 entries, 0 to 646
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     647 non-null    float64
#  1   Right_Shoulder_Angle    647 non-null    float64
#  2   Left_Elbow_Angle        647 non-null    float64
#  3   Right_Elbow_Angle       647 non-null    float64
#  4   Left_Wrist_Angle        647 non-null    float64
#  5   Right_Wrist_Angle       647 non-null    float64
#  6   Left_Hip_Angle          647 non-null    float64
#  7   Right_Hip_Angle         647 non-null    float64
#  8   Left_Knee_Angle         647 non-null    float64
#  9   Right_Knee_Angle        647 non-null    float64
#  10  Neck_Angle              647 non-null    float64
#  11  Left_Ankle_Angle        647 non-null    float64
#  12  Right_Ankle_Angle       647 non-null    float64
#  13  Left_Heel_Angle         647 non-null    float64
#  14  Right_Heel_Angle        647 non-null    float64
#  15  Left_Foot_Index_Angle   647 non-null    float64
#  16  Right_Foot_Index_Angle  647 non-null    float64
#  17  Label                   647 non-null    int64
# dtypes: float64(17), int64(1)
# memory usage: 91.1 KB
# None
# File in process : Copy of push up 116.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722 entries, 0 to 721
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     722 non-null    float64
#  1   Right_Shoulder_Angle    722 non-null    float64
#  2   Left_Elbow_Angle        722 non-null    float64
#  3   Right_Elbow_Angle       722 non-null    float64
#  4   Left_Wrist_Angle        722 non-null    float64
#  5   Right_Wrist_Angle       722 non-null    float64
#  6   Left_Hip_Angle          722 non-null    float64
#  7   Right_Hip_Angle         722 non-null    float64
#  8   Left_Knee_Angle         722 non-null    float64
#  9   Right_Knee_Angle        722 non-null    float64
#  10  Neck_Angle              722 non-null    float64
#  11  Left_Ankle_Angle        722 non-null    float64
#  12  Right_Ankle_Angle       722 non-null    float64
#  13  Left_Heel_Angle         722 non-null    float64
#  14  Right_Heel_Angle        722 non-null    float64
#  15  Left_Foot_Index_Angle   722 non-null    float64
#  16  Right_Foot_Index_Angle  722 non-null    float64
#  17  Label                   722 non-null    int64
# dtypes: float64(17), int64(1)
# memory usage: 101.7 KB
# None
# File in process : Copy of push up 127.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 813 entries, 0 to 812
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     813 non-null    float64
#  1   Right_Shoulder_Angle    813 non-null    float64
#  2   Left_Elbow_Angle        813 non-null    float64
#  3   Right_Elbow_Angle       813 non-null    float64
#  4   Left_Wrist_Angle        813 non-null    float64
#  5   Right_Wrist_Angle       813 non-null    float64
#  6   Left_Hip_Angle          813 non-null    float64
#  7   Right_Hip_Angle         813 non-null    float64
#  8   Left_Knee_Angle         813 non-null    float64
#  9   Right_Knee_Angle        813 non-null    float64
#  10  Neck_Angle              813 non-null    float64
#  11  Left_Ankle_Angle        813 non-null    float64
#  12  Right_Ankle_Angle       813 non-null    float64
#  13  Left_Heel_Angle         813 non-null    float64
#  14  Right_Heel_Angle        813 non-null    float64
#  15  Left_Foot_Index_Angle   813 non-null    float64
#  16  Right_Foot_Index_Angle  813 non-null    float64
#  17  Label                   813 non-null    int64
# dtypes: float64(17), int64(1)
# memory usage: 114.5 KB
# None
# File in process : Copy of push up 129.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 897 entries, 0 to 896
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     897 non-null    float64
#  1   Right_Shoulder_Angle    897 non-null    float64
#  2   Left_Elbow_Angle        897 non-null    float64
#  3   Right_Elbow_Angle       897 non-null    float64
#  4   Left_Wrist_Angle        897 non-null    float64
#  5   Right_Wrist_Angle       897 non-null    float64
#  6   Left_Hip_Angle          897 non-null    float64
#  7   Right_Hip_Angle         897 non-null    float64
#  8   Left_Knee_Angle         897 non-null    float64
#  9   Right_Knee_Angle        897 non-null    float64
#  10  Neck_Angle              897 non-null    float64
#  11  Left_Ankle_Angle        897 non-null    float64
#  12  Right_Ankle_Angle       897 non-null    float64
#  13  Left_Heel_Angle         897 non-null    float64
#  14  Right_Heel_Angle        897 non-null    float64
#  15  Left_Foot_Index_Angle   897 non-null    float64
#  16  Right_Foot_Index_Angle  897 non-null    float64
#  17  Label                   897 non-null    int64
# dtypes: float64(17), int64(1)
# memory usage: 126.3 KB
# None
# File in process : Copy of push up 131.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 974 entries, 0 to 973
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     974 non-null    float64
#  1   Right_Shoulder_Angle    974 non-null    float64
#  2   Left_Elbow_Angle        974 non-null    float64
#  3   Right_Elbow_Angle       974 non-null    float64
#  4   Left_Wrist_Angle        974 non-null    float64
#  5   Right_Wrist_Angle       974 non-null    float64
#  6   Left_Hip_Angle          974 non-null    float64
#  7   Right_Hip_Angle         974 non-null    float64
#  8   Left_Knee_Angle         974 non-null    float64
#  9   Right_Knee_Angle        974 non-null    float64
#  10  Neck_Angle              974 non-null    float64
#  11  Left_Ankle_Angle        974 non-null    float64
#  12  Right_Ankle_Angle       974 non-null    float64
#  13  Left_Heel_Angle         974 non-null    float64
#  14  Right_Heel_Angle        974 non-null    float64
#  15  Left_Foot_Index_Angle   974 non-null    float64
#  16  Right_Foot_Index_Angle  974 non-null    float64
#  17  Label                   974 non-null    int64
# dtypes: float64(17), int64(1)
# memory usage: 137.1 KB
# None
# File in process : Copy of push up 132.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1053 entries, 0 to 1052
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1053 non-null   float64
#  1   Right_Shoulder_Angle    1053 non-null   float64
#  2   Left_Elbow_Angle        1053 non-null   float64
#  3   Right_Elbow_Angle       1053 non-null   float64
#  4   Left_Wrist_Angle        1053 non-null   float64
#  5   Right_Wrist_Angle       1053 non-null   float64
#  6   Left_Hip_Angle          1053 non-null   float64
#  7   Right_Hip_Angle         1053 non-null   float64
#  8   Left_Knee_Angle         1053 non-null   float64
#  9   Right_Knee_Angle        1053 non-null   float64
#  10  Neck_Angle              1053 non-null   float64
#  11  Left_Ankle_Angle        1053 non-null   float64
#  12  Right_Ankle_Angle       1053 non-null   float64
#  13  Left_Heel_Angle         1053 non-null   float64
#  14  Right_Heel_Angle        1053 non-null   float64
#  15  Left_Foot_Index_Angle   1053 non-null   float64
#  16  Right_Foot_Index_Angle  1053 non-null   float64
#  17  Label                   1053 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 148.2 KB
# None
# File in process : Copy of push up 133.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1129 entries, 0 to 1128
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1129 non-null   float64
#  1   Right_Shoulder_Angle    1129 non-null   float64
#  2   Left_Elbow_Angle        1129 non-null   float64
#  3   Right_Elbow_Angle       1129 non-null   float64
#  4   Left_Wrist_Angle        1129 non-null   float64
#  5   Right_Wrist_Angle       1129 non-null   float64
#  6   Left_Hip_Angle          1129 non-null   float64
#  7   Right_Hip_Angle         1129 non-null   float64
#  8   Left_Knee_Angle         1129 non-null   float64
#  9   Right_Knee_Angle        1129 non-null   float64
#  10  Neck_Angle              1129 non-null   float64
#  11  Left_Ankle_Angle        1129 non-null   float64
#  12  Right_Ankle_Angle       1129 non-null   float64
#  13  Left_Heel_Angle         1129 non-null   float64
#  14  Right_Heel_Angle        1129 non-null   float64
#  15  Left_Foot_Index_Angle   1129 non-null   float64
#  16  Right_Foot_Index_Angle  1129 non-null   float64
#  17  Label                   1129 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 158.9 KB
# None
# File in process : Copy of push up 134.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1204 entries, 0 to 1203
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1204 non-null   float64
#  1   Right_Shoulder_Angle    1204 non-null   float64
#  2   Left_Elbow_Angle        1204 non-null   float64
#  3   Right_Elbow_Angle       1204 non-null   float64
#  4   Left_Wrist_Angle        1204 non-null   float64
#  5   Right_Wrist_Angle       1204 non-null   float64
#  6   Left_Hip_Angle          1204 non-null   float64
#  7   Right_Hip_Angle         1204 non-null   float64
#  8   Left_Knee_Angle         1204 non-null   float64
#  9   Right_Knee_Angle        1204 non-null   float64
#  10  Neck_Angle              1204 non-null   float64
#  11  Left_Ankle_Angle        1204 non-null   float64
#  12  Right_Ankle_Angle       1204 non-null   float64
#  13  Left_Heel_Angle         1204 non-null   float64
#  14  Right_Heel_Angle        1204 non-null   float64
#  15  Left_Foot_Index_Angle   1204 non-null   float64
#  16  Right_Foot_Index_Angle  1204 non-null   float64
#  17  Label                   1204 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 169.4 KB
# None
# File in process : Copy of push up 135.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1276 non-null   float64
#  1   Right_Shoulder_Angle    1276 non-null   float64
#  2   Left_Elbow_Angle        1276 non-null   float64
#  3   Right_Elbow_Angle       1276 non-null   float64
#  4   Left_Wrist_Angle        1276 non-null   float64
#  5   Right_Wrist_Angle       1276 non-null   float64
#  6   Left_Hip_Angle          1276 non-null   float64
#  7   Right_Hip_Angle         1276 non-null   float64
#  8   Left_Knee_Angle         1276 non-null   float64
#  9   Right_Knee_Angle        1276 non-null   float64
#  10  Neck_Angle              1276 non-null   float64
#  11  Left_Ankle_Angle        1276 non-null   float64
#  12  Right_Ankle_Angle       1276 non-null   float64
#  13  Left_Heel_Angle         1276 non-null   float64
#  14  Right_Heel_Angle        1276 non-null   float64
#  15  Left_Foot_Index_Angle   1276 non-null   float64
#  16  Right_Foot_Index_Angle  1276 non-null   float64
#  17  Label                   1276 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 179.6 KB
# None
# File in process : Copy of push up 136.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1351 entries, 0 to 1350
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1351 non-null   float64
#  1   Right_Shoulder_Angle    1351 non-null   float64
#  2   Left_Elbow_Angle        1351 non-null   float64
#  3   Right_Elbow_Angle       1351 non-null   float64
#  4   Left_Wrist_Angle        1351 non-null   float64
#  5   Right_Wrist_Angle       1351 non-null   float64
#  6   Left_Hip_Angle          1351 non-null   float64
#  7   Right_Hip_Angle         1351 non-null   float64
#  8   Left_Knee_Angle         1351 non-null   float64
#  9   Right_Knee_Angle        1351 non-null   float64
#  10  Neck_Angle              1351 non-null   float64
#  11  Left_Ankle_Angle        1351 non-null   float64
#  12  Right_Ankle_Angle       1351 non-null   float64
#  13  Left_Heel_Angle         1351 non-null   float64
#  14  Right_Heel_Angle        1351 non-null   float64
#  15  Left_Foot_Index_Angle   1351 non-null   float64
#  16  Right_Foot_Index_Angle  1351 non-null   float64
#  17  Label                   1351 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 190.1 KB
# None
# File in process : Copy of push up 137.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1422 entries, 0 to 1421
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1422 non-null   float64
#  1   Right_Shoulder_Angle    1422 non-null   float64
#  2   Left_Elbow_Angle        1422 non-null   float64
#  3   Right_Elbow_Angle       1422 non-null   float64
#  4   Left_Wrist_Angle        1422 non-null   float64
#  5   Right_Wrist_Angle       1422 non-null   float64
#  6   Left_Hip_Angle          1422 non-null   float64
#  7   Right_Hip_Angle         1422 non-null   float64
#  8   Left_Knee_Angle         1422 non-null   float64
#  9   Right_Knee_Angle        1422 non-null   float64
#  10  Neck_Angle              1422 non-null   float64
#  11  Left_Ankle_Angle        1422 non-null   float64
#  12  Right_Ankle_Angle       1422 non-null   float64
#  13  Left_Heel_Angle         1422 non-null   float64
#  14  Right_Heel_Angle        1422 non-null   float64
#  15  Left_Foot_Index_Angle   1422 non-null   float64
#  16  Right_Foot_Index_Angle  1422 non-null   float64
#  17  Label                   1422 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 200.1 KB
# None
# File in process : Copy of push up 138.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1496 entries, 0 to 1495
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1496 non-null   float64
#  1   Right_Shoulder_Angle    1496 non-null   float64
#  2   Left_Elbow_Angle        1496 non-null   float64
#  3   Right_Elbow_Angle       1496 non-null   float64
#  4   Left_Wrist_Angle        1496 non-null   float64
#  5   Right_Wrist_Angle       1496 non-null   float64
#  6   Left_Hip_Angle          1496 non-null   float64
#  7   Right_Hip_Angle         1496 non-null   float64
#  8   Left_Knee_Angle         1496 non-null   float64
#  9   Right_Knee_Angle        1496 non-null   float64
#  10  Neck_Angle              1496 non-null   float64
#  11  Left_Ankle_Angle        1496 non-null   float64
#  12  Right_Ankle_Angle       1496 non-null   float64
#  13  Left_Heel_Angle         1496 non-null   float64
#  14  Right_Heel_Angle        1496 non-null   float64
#  15  Left_Foot_Index_Angle   1496 non-null   float64
#  16  Right_Foot_Index_Angle  1496 non-null   float64
#  17  Label                   1496 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 210.5 KB
# None
# File in process : Copy of push up 140.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1583 entries, 0 to 1582
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1583 non-null   float64
#  1   Right_Shoulder_Angle    1583 non-null   float64
#  2   Left_Elbow_Angle        1583 non-null   float64
#  3   Right_Elbow_Angle       1583 non-null   float64
#  4   Left_Wrist_Angle        1583 non-null   float64
#  5   Right_Wrist_Angle       1583 non-null   float64
#  6   Left_Hip_Angle          1583 non-null   float64
#  7   Right_Hip_Angle         1583 non-null   float64
#  8   Left_Knee_Angle         1583 non-null   float64
#  9   Right_Knee_Angle        1583 non-null   float64
#  10  Neck_Angle              1583 non-null   float64
#  11  Left_Ankle_Angle        1583 non-null   float64
#  12  Right_Ankle_Angle       1583 non-null   float64
#  13  Left_Heel_Angle         1583 non-null   float64
#  14  Right_Heel_Angle        1583 non-null   float64
#  15  Left_Foot_Index_Angle   1583 non-null   float64
#  16  Right_Foot_Index_Angle  1583 non-null   float64
#  17  Label                   1583 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 222.7 KB
# None
# File in process : Copy of push up 141.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1674 entries, 0 to 1673
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1674 non-null   float64
#  1   Right_Shoulder_Angle    1674 non-null   float64
#  2   Left_Elbow_Angle        1674 non-null   float64
#  3   Right_Elbow_Angle       1674 non-null   float64
#  4   Left_Wrist_Angle        1674 non-null   float64
#  5   Right_Wrist_Angle       1674 non-null   float64
#  6   Left_Hip_Angle          1674 non-null   float64
#  7   Right_Hip_Angle         1674 non-null   float64
#  8   Left_Knee_Angle         1674 non-null   float64
#  9   Right_Knee_Angle        1674 non-null   float64
#  10  Neck_Angle              1674 non-null   float64
#  11  Left_Ankle_Angle        1674 non-null   float64
#  12  Right_Ankle_Angle       1674 non-null   float64
#  13  Left_Heel_Angle         1674 non-null   float64
#  14  Right_Heel_Angle        1674 non-null   float64
#  15  Left_Foot_Index_Angle   1674 non-null   float64
#  16  Right_Foot_Index_Angle  1674 non-null   float64
#  17  Label                   1674 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 235.5 KB
# None
# File in process : Copy of push up 142.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1766 entries, 0 to 1765
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1766 non-null   float64
#  1   Right_Shoulder_Angle    1766 non-null   float64
#  2   Left_Elbow_Angle        1766 non-null   float64
#  3   Right_Elbow_Angle       1766 non-null   float64
#  4   Left_Wrist_Angle        1766 non-null   float64
#  5   Right_Wrist_Angle       1766 non-null   float64
#  6   Left_Hip_Angle          1766 non-null   float64
#  7   Right_Hip_Angle         1766 non-null   float64
#  8   Left_Knee_Angle         1766 non-null   float64
#  9   Right_Knee_Angle        1766 non-null   float64
#  10  Neck_Angle              1766 non-null   float64
#  11  Left_Ankle_Angle        1766 non-null   float64
#  12  Right_Ankle_Angle       1766 non-null   float64
#  13  Left_Heel_Angle         1766 non-null   float64
#  14  Right_Heel_Angle        1766 non-null   float64
#  15  Left_Foot_Index_Angle   1766 non-null   float64
#  16  Right_Foot_Index_Angle  1766 non-null   float64
#  17  Label                   1766 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 248.5 KB
# None
# File in process : Copy of push up 144.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1856 entries, 0 to 1855
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1856 non-null   float64
#  1   Right_Shoulder_Angle    1856 non-null   float64
#  2   Left_Elbow_Angle        1856 non-null   float64
#  3   Right_Elbow_Angle       1856 non-null   float64
#  4   Left_Wrist_Angle        1856 non-null   float64
#  5   Right_Wrist_Angle       1856 non-null   float64
#  6   Left_Hip_Angle          1856 non-null   float64
#  7   Right_Hip_Angle         1856 non-null   float64
#  8   Left_Knee_Angle         1856 non-null   float64
#  9   Right_Knee_Angle        1856 non-null   float64
#  10  Neck_Angle              1856 non-null   float64
#  11  Left_Ankle_Angle        1856 non-null   float64
#  12  Right_Ankle_Angle       1856 non-null   float64
#  13  Left_Heel_Angle         1856 non-null   float64
#  14  Right_Heel_Angle        1856 non-null   float64
#  15  Left_Foot_Index_Angle   1856 non-null   float64
#  16  Right_Foot_Index_Angle  1856 non-null   float64
#  17  Label                   1856 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 261.1 KB
# None
# File in process : Copy of push up 146.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1963 entries, 0 to 1962
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     1963 non-null   float64
#  1   Right_Shoulder_Angle    1963 non-null   float64
#  2   Left_Elbow_Angle        1963 non-null   float64
#  3   Right_Elbow_Angle       1963 non-null   float64
#  4   Left_Wrist_Angle        1963 non-null   float64
#  5   Right_Wrist_Angle       1963 non-null   float64
#  6   Left_Hip_Angle          1963 non-null   float64
#  7   Right_Hip_Angle         1963 non-null   float64
#  8   Left_Knee_Angle         1963 non-null   float64
#  9   Right_Knee_Angle        1963 non-null   float64
#  10  Neck_Angle              1963 non-null   float64
#  11  Left_Ankle_Angle        1963 non-null   float64
#  12  Right_Ankle_Angle       1963 non-null   float64
#  13  Left_Heel_Angle         1963 non-null   float64
#  14  Right_Heel_Angle        1963 non-null   float64
#  15  Left_Foot_Index_Angle   1963 non-null   float64
#  16  Right_Foot_Index_Angle  1963 non-null   float64
#  17  Label                   1963 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 276.2 KB
# None
# File in process : Copy of push up 147.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2086 entries, 0 to 2085
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     2086 non-null   float64
#  1   Right_Shoulder_Angle    2086 non-null   float64
#  2   Left_Elbow_Angle        2086 non-null   float64
#  3   Right_Elbow_Angle       2086 non-null   float64
#  4   Left_Wrist_Angle        2086 non-null   float64
#  5   Right_Wrist_Angle       2086 non-null   float64
#  6   Left_Hip_Angle          2086 non-null   float64
#  7   Right_Hip_Angle         2086 non-null   float64
#  8   Left_Knee_Angle         2086 non-null   float64
#  9   Right_Knee_Angle        2086 non-null   float64
#  10  Neck_Angle              2086 non-null   float64
#  11  Left_Ankle_Angle        2086 non-null   float64
#  12  Right_Ankle_Angle       2086 non-null   float64
#  13  Left_Heel_Angle         2086 non-null   float64
#  14  Right_Heel_Angle        2086 non-null   float64
#  15  Left_Foot_Index_Angle   2086 non-null   float64
#  16  Right_Foot_Index_Angle  2086 non-null   float64
#  17  Label                   2086 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 293.5 KB
# None
# File in process : Copy of push up 148.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2219 entries, 0 to 2218
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     2219 non-null   float64
#  1   Right_Shoulder_Angle    2219 non-null   float64
#  2   Left_Elbow_Angle        2219 non-null   float64
#  3   Right_Elbow_Angle       2219 non-null   float64
#  4   Left_Wrist_Angle        2219 non-null   float64
#  5   Right_Wrist_Angle       2219 non-null   float64
#  6   Left_Hip_Angle          2219 non-null   float64
#  7   Right_Hip_Angle         2219 non-null   float64
#  8   Left_Knee_Angle         2219 non-null   float64
#  9   Right_Knee_Angle        2219 non-null   float64
#  10  Neck_Angle              2219 non-null   float64
#  11  Left_Ankle_Angle        2219 non-null   float64
#  12  Right_Ankle_Angle       2219 non-null   float64
#  13  Left_Heel_Angle         2219 non-null   float64
#  14  Right_Heel_Angle        2219 non-null   float64
#  15  Left_Foot_Index_Angle   2219 non-null   float64
#  16  Right_Foot_Index_Angle  2219 non-null   float64
#  17  Label                   2219 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 312.2 KB
# None
# File in process : Copy of push up 162.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2326 entries, 0 to 2325
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     2326 non-null   float64
#  1   Right_Shoulder_Angle    2326 non-null   float64
#  2   Left_Elbow_Angle        2326 non-null   float64
#  3   Right_Elbow_Angle       2326 non-null   float64
#  4   Left_Wrist_Angle        2326 non-null   float64
#  5   Right_Wrist_Angle       2326 non-null   float64
#  6   Left_Hip_Angle          2326 non-null   float64
#  7   Right_Hip_Angle         2326 non-null   float64
#  8   Left_Knee_Angle         2326 non-null   float64
#  9   Right_Knee_Angle        2326 non-null   float64
#  10  Neck_Angle              2326 non-null   float64
#  11  Left_Ankle_Angle        2326 non-null   float64
#  12  Right_Ankle_Angle       2326 non-null   float64
#  13  Left_Heel_Angle         2326 non-null   float64
#  14  Right_Heel_Angle        2326 non-null   float64
#  15  Left_Foot_Index_Angle   2326 non-null   float64
#  16  Right_Foot_Index_Angle  2326 non-null   float64
#  17  Label                   2326 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 327.2 KB
# None
# File in process : Copy of push up 163.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2424 entries, 0 to 2423
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     2424 non-null   float64
#  1   Right_Shoulder_Angle    2424 non-null   float64
#  2   Left_Elbow_Angle        2424 non-null   float64
#  3   Right_Elbow_Angle       2424 non-null   float64
#  4   Left_Wrist_Angle        2424 non-null   float64
#  5   Right_Wrist_Angle       2424 non-null   float64
#  6   Left_Hip_Angle          2424 non-null   float64
#  7   Right_Hip_Angle         2424 non-null   float64
#  8   Left_Knee_Angle         2424 non-null   float64
#  9   Right_Knee_Angle        2424 non-null   float64
#  10  Neck_Angle              2424 non-null   float64
#  11  Left_Ankle_Angle        2424 non-null   float64
#  12  Right_Ankle_Angle       2424 non-null   float64
#  13  Left_Heel_Angle         2424 non-null   float64
#  14  Right_Heel_Angle        2424 non-null   float64
#  15  Left_Foot_Index_Angle   2424 non-null   float64
#  16  Right_Foot_Index_Angle  2424 non-null   float64
#  17  Label                   2424 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 341.0 KB
# None
# File in process : Copy of push up 164.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2539 entries, 0 to 2538
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     2539 non-null   float64
#  1   Right_Shoulder_Angle    2539 non-null   float64
#  2   Left_Elbow_Angle        2539 non-null   float64
#  3   Right_Elbow_Angle       2539 non-null   float64
#  4   Left_Wrist_Angle        2539 non-null   float64
#  5   Right_Wrist_Angle       2539 non-null   float64
#  6   Left_Hip_Angle          2539 non-null   float64
#  7   Right_Hip_Angle         2539 non-null   float64
#  8   Left_Knee_Angle         2539 non-null   float64
#  9   Right_Knee_Angle        2539 non-null   float64
#  10  Neck_Angle              2539 non-null   float64
#  11  Left_Ankle_Angle        2539 non-null   float64
#  12  Right_Ankle_Angle       2539 non-null   float64
#  13  Left_Heel_Angle         2539 non-null   float64
#  14  Right_Heel_Angle        2539 non-null   float64
#  15  Left_Foot_Index_Angle   2539 non-null   float64
#  16  Right_Foot_Index_Angle  2539 non-null   float64
#  17  Label                   2539 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 357.2 KB
# None
# File in process : Copy of push up 165.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2639 entries, 0 to 2638
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     2639 non-null   float64
#  1   Right_Shoulder_Angle    2639 non-null   float64
#  2   Left_Elbow_Angle        2639 non-null   float64
#  3   Right_Elbow_Angle       2639 non-null   float64
#  4   Left_Wrist_Angle        2639 non-null   float64
#  5   Right_Wrist_Angle       2639 non-null   float64
#  6   Left_Hip_Angle          2639 non-null   float64
#  7   Right_Hip_Angle         2639 non-null   float64
#  8   Left_Knee_Angle         2639 non-null   float64
#  9   Right_Knee_Angle        2639 non-null   float64
#  10  Neck_Angle              2639 non-null   float64
#  11  Left_Ankle_Angle        2639 non-null   float64
#  12  Right_Ankle_Angle       2639 non-null   float64
#  13  Left_Heel_Angle         2639 non-null   float64
#  14  Right_Heel_Angle        2639 non-null   float64
#  15  Left_Foot_Index_Angle   2639 non-null   float64
#  16  Right_Foot_Index_Angle  2639 non-null   float64
#  17  Label                   2639 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 371.2 KB
# None
# File in process : Copy of push up 173.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2792 entries, 0 to 2791
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     2792 non-null   float64
#  1   Right_Shoulder_Angle    2792 non-null   float64
#  2   Left_Elbow_Angle        2792 non-null   float64
#  3   Right_Elbow_Angle       2792 non-null   float64
#  4   Left_Wrist_Angle        2792 non-null   float64
#  5   Right_Wrist_Angle       2792 non-null   float64
#  6   Left_Hip_Angle          2792 non-null   float64
#  7   Right_Hip_Angle         2792 non-null   float64
#  8   Left_Knee_Angle         2792 non-null   float64
#  9   Right_Knee_Angle        2792 non-null   float64
#  10  Neck_Angle              2792 non-null   float64
#  11  Left_Ankle_Angle        2792 non-null   float64
#  12  Right_Ankle_Angle       2792 non-null   float64
#  13  Left_Heel_Angle         2792 non-null   float64
#  14  Right_Heel_Angle        2792 non-null   float64
#  15  Left_Foot_Index_Angle   2792 non-null   float64
#  16  Right_Foot_Index_Angle  2792 non-null   float64
#  17  Label                   2792 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 392.8 KB
# None
# File in process : Copy of push up 174.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2923 entries, 0 to 2922
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     2923 non-null   float64
#  1   Right_Shoulder_Angle    2923 non-null   float64
#  2   Left_Elbow_Angle        2923 non-null   float64
#  3   Right_Elbow_Angle       2923 non-null   float64
#  4   Left_Wrist_Angle        2923 non-null   float64
#  5   Right_Wrist_Angle       2923 non-null   float64
#  6   Left_Hip_Angle          2923 non-null   float64
#  7   Right_Hip_Angle         2923 non-null   float64
#  8   Left_Knee_Angle         2923 non-null   float64
#  9   Right_Knee_Angle        2923 non-null   float64
#  10  Neck_Angle              2923 non-null   float64
#  11  Left_Ankle_Angle        2923 non-null   float64
#  12  Right_Ankle_Angle       2923 non-null   float64
#  13  Left_Heel_Angle         2923 non-null   float64
#  14  Right_Heel_Angle        2923 non-null   float64
#  15  Left_Foot_Index_Angle   2923 non-null   float64
#  16  Right_Foot_Index_Angle  2923 non-null   float64
#  17  Label                   2923 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 411.2 KB
# None
# File in process : Copy of push up 175.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3033 entries, 0 to 3032
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     3033 non-null   float64
#  1   Right_Shoulder_Angle    3033 non-null   float64
#  2   Left_Elbow_Angle        3033 non-null   float64
#  3   Right_Elbow_Angle       3033 non-null   float64
#  4   Left_Wrist_Angle        3033 non-null   float64
#  5   Right_Wrist_Angle       3033 non-null   float64
#  6   Left_Hip_Angle          3033 non-null   float64
#  7   Right_Hip_Angle         3033 non-null   float64
#  8   Left_Knee_Angle         3033 non-null   float64
#  9   Right_Knee_Angle        3033 non-null   float64
#  10  Neck_Angle              3033 non-null   float64
#  11  Left_Ankle_Angle        3033 non-null   float64
#  12  Right_Ankle_Angle       3033 non-null   float64
#  13  Left_Heel_Angle         3033 non-null   float64
#  14  Right_Heel_Angle        3033 non-null   float64
#  15  Left_Foot_Index_Angle   3033 non-null   float64
#  16  Right_Foot_Index_Angle  3033 non-null   float64
#  17  Label                   3033 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 426.6 KB
# None
# File in process : Copy of push up 177.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3179 entries, 0 to 3178
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     3179 non-null   float64
#  1   Right_Shoulder_Angle    3179 non-null   float64
#  2   Left_Elbow_Angle        3179 non-null   float64
#  3   Right_Elbow_Angle       3179 non-null   float64
#  4   Left_Wrist_Angle        3179 non-null   float64
#  5   Right_Wrist_Angle       3179 non-null   float64
#  6   Left_Hip_Angle          3179 non-null   float64
#  7   Right_Hip_Angle         3179 non-null   float64
#  8   Left_Knee_Angle         3179 non-null   float64
#  9   Right_Knee_Angle        3179 non-null   float64
#  10  Neck_Angle              3179 non-null   float64
#  11  Left_Ankle_Angle        3179 non-null   float64
#  12  Right_Ankle_Angle       3179 non-null   float64
#  13  Left_Heel_Angle         3179 non-null   float64
#  14  Right_Heel_Angle        3179 non-null   float64
#  15  Left_Foot_Index_Angle   3179 non-null   float64
#  16  Right_Foot_Index_Angle  3179 non-null   float64
#  17  Label                   3179 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 447.2 KB
# None
# File in process : Copy of push up 178.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3327 entries, 0 to 3326
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     3327 non-null   float64
#  1   Right_Shoulder_Angle    3327 non-null   float64
#  2   Left_Elbow_Angle        3327 non-null   float64
#  3   Right_Elbow_Angle       3327 non-null   float64
#  4   Left_Wrist_Angle        3327 non-null   float64
#  5   Right_Wrist_Angle       3327 non-null   float64
#  6   Left_Hip_Angle          3327 non-null   float64
#  7   Right_Hip_Angle         3327 non-null   float64
#  8   Left_Knee_Angle         3327 non-null   float64
#  9   Right_Knee_Angle        3327 non-null   float64
#  10  Neck_Angle              3327 non-null   float64
#  11  Left_Ankle_Angle        3327 non-null   float64
#  12  Right_Ankle_Angle       3327 non-null   float64
#  13  Left_Heel_Angle         3327 non-null   float64
#  14  Right_Heel_Angle        3327 non-null   float64
#  15  Left_Foot_Index_Angle   3327 non-null   float64
#  16  Right_Foot_Index_Angle  3327 non-null   float64
#  17  Label                   3327 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 468.0 KB
# None
# File in process : Copy of push up 186.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3395 entries, 0 to 3394
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     3395 non-null   float64
#  1   Right_Shoulder_Angle    3395 non-null   float64
#  2   Left_Elbow_Angle        3395 non-null   float64
#  3   Right_Elbow_Angle       3395 non-null   float64
#  4   Left_Wrist_Angle        3395 non-null   float64
#  5   Right_Wrist_Angle       3395 non-null   float64
#  6   Left_Hip_Angle          3395 non-null   float64
#  7   Right_Hip_Angle         3395 non-null   float64
#  8   Left_Knee_Angle         3395 non-null   float64
#  9   Right_Knee_Angle        3395 non-null   float64
#  10  Neck_Angle              3395 non-null   float64
#  11  Left_Ankle_Angle        3395 non-null   float64
#  12  Right_Ankle_Angle       3395 non-null   float64
#  13  Left_Heel_Angle         3395 non-null   float64
#  14  Right_Heel_Angle        3395 non-null   float64
#  15  Left_Foot_Index_Angle   3395 non-null   float64
#  16  Right_Foot_Index_Angle  3395 non-null   float64
#  17  Label                   3395 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 477.5 KB
# None
# File in process : Copy of push up 187.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3465 entries, 0 to 3464
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     3465 non-null   float64
#  1   Right_Shoulder_Angle    3465 non-null   float64
#  2   Left_Elbow_Angle        3465 non-null   float64
#  3   Right_Elbow_Angle       3465 non-null   float64
#  4   Left_Wrist_Angle        3465 non-null   float64
#  5   Right_Wrist_Angle       3465 non-null   float64
#  6   Left_Hip_Angle          3465 non-null   float64
#  7   Right_Hip_Angle         3465 non-null   float64
#  8   Left_Knee_Angle         3465 non-null   float64
#  9   Right_Knee_Angle        3465 non-null   float64
#  10  Neck_Angle              3465 non-null   float64
#  11  Left_Ankle_Angle        3465 non-null   float64
#  12  Right_Ankle_Angle       3465 non-null   float64
#  13  Left_Heel_Angle         3465 non-null   float64
#  14  Right_Heel_Angle        3465 non-null   float64
#  15  Left_Foot_Index_Angle   3465 non-null   float64
#  16  Right_Foot_Index_Angle  3465 non-null   float64
#  17  Label                   3465 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 487.4 KB
# None
# File in process : Copy of push up 188.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3534 entries, 0 to 3533
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     3534 non-null   float64
#  1   Right_Shoulder_Angle    3534 non-null   float64
#  2   Left_Elbow_Angle        3534 non-null   float64
#  3   Right_Elbow_Angle       3534 non-null   float64
#  4   Left_Wrist_Angle        3534 non-null   float64
#  5   Right_Wrist_Angle       3534 non-null   float64
#  6   Left_Hip_Angle          3534 non-null   float64
#  7   Right_Hip_Angle         3534 non-null   float64
#  8   Left_Knee_Angle         3534 non-null   float64
#  9   Right_Knee_Angle        3534 non-null   float64
#  10  Neck_Angle              3534 non-null   float64
#  11  Left_Ankle_Angle        3534 non-null   float64
#  12  Right_Ankle_Angle       3534 non-null   float64
#  13  Left_Heel_Angle         3534 non-null   float64
#  14  Right_Heel_Angle        3534 non-null   float64
#  15  Left_Foot_Index_Angle   3534 non-null   float64
#  16  Right_Foot_Index_Angle  3534 non-null   float64
#  17  Label                   3534 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 497.1 KB
# None
# File in process : Copy of push up 197.mp4
# Label: True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3690 entries, 0 to 3689
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     3690 non-null   float64
#  1   Right_Shoulder_Angle    3690 non-null   float64
#  2   Left_Elbow_Angle        3690 non-null   float64
#  3   Right_Elbow_Angle       3690 non-null   float64
#  4   Left_Wrist_Angle        3690 non-null   float64
#  5   Right_Wrist_Angle       3690 non-null   float64
#  6   Left_Hip_Angle          3690 non-null   float64
# ...
#  8   Left_Knee_Angle         9384 non-null   float64
#  9   Right_Knee_Angle        9384 non-null   float64
#  10  Neck_Angle              9384 non-null   float64
#  11  Left_Ankle_Angle        9384 non-null   float64
#  12  Right_Ankle_Angle       9384 non-null   float64
#  13  Left_Heel_Angle         9384 non-null   float64
#  14  Right_Heel_Angle        9384 non-null   float64
#  15  Left_Foot_Index_Angle   9384 non-null   float64
#  16  Right_Foot_Index_Angle  9384 non-null   float64
#  17  Label                   9384 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 1.3 MB
# None
# File in process : Copy of push up 171.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9781 entries, 0 to 9780
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     9781 non-null   float64
#  1   Right_Shoulder_Angle    9781 non-null   float64
#  2   Left_Elbow_Angle        9781 non-null   float64
#  3   Right_Elbow_Angle       9781 non-null   float64
#  4   Left_Wrist_Angle        9781 non-null   float64
#  5   Right_Wrist_Angle       9781 non-null   float64
#  6   Left_Hip_Angle          9781 non-null   float64
#  7   Right_Hip_Angle         9781 non-null   float64
#  8   Left_Knee_Angle         9781 non-null   float64
#  9   Right_Knee_Angle        9781 non-null   float64
#  10  Neck_Angle              9781 non-null   float64
#  11  Left_Ankle_Angle        9781 non-null   float64
#  12  Right_Ankle_Angle       9781 non-null   float64
#  13  Left_Heel_Angle         9781 non-null   float64
#  14  Right_Heel_Angle        9781 non-null   float64
#  15  Left_Foot_Index_Angle   9781 non-null   float64
#  16  Right_Foot_Index_Angle  9781 non-null   float64
#  17  Label                   9781 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 1.3 MB
# None
# File in process : Copy of push up 198.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9992 entries, 0 to 9991
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     9992 non-null   float64
#  1   Right_Shoulder_Angle    9992 non-null   float64
#  2   Left_Elbow_Angle        9992 non-null   float64
#  3   Right_Elbow_Angle       9992 non-null   float64
#  4   Left_Wrist_Angle        9992 non-null   float64
#  5   Right_Wrist_Angle       9992 non-null   float64
#  6   Left_Hip_Angle          9992 non-null   float64
#  7   Right_Hip_Angle         9992 non-null   float64
#  8   Left_Knee_Angle         9992 non-null   float64
#  9   Right_Knee_Angle        9992 non-null   float64
#  10  Neck_Angle              9992 non-null   float64
#  11  Left_Ankle_Angle        9992 non-null   float64
#  12  Right_Ankle_Angle       9992 non-null   float64
#  13  Left_Heel_Angle         9992 non-null   float64
#  14  Right_Heel_Angle        9992 non-null   float64
#  15  Left_Foot_Index_Angle   9992 non-null   float64
#  16  Right_Foot_Index_Angle  9992 non-null   float64
#  17  Label                   9992 non-null   int64
# dtypes: float64(17), int64(1)
# memory usage: 1.4 MB
# None
# File in process : Copy of push up 36.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10075 entries, 0 to 10074
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     10075 non-null  float64
#  1   Right_Shoulder_Angle    10075 non-null  float64
#  2   Left_Elbow_Angle        10075 non-null  float64
#  3   Right_Elbow_Angle       10075 non-null  float64
#  4   Left_Wrist_Angle        10075 non-null  float64
#  5   Right_Wrist_Angle       10075 non-null  float64
#  6   Left_Hip_Angle          10075 non-null  float64
#  7   Right_Hip_Angle         10075 non-null  float64
#  8   Left_Knee_Angle         10075 non-null  float64
#  9   Right_Knee_Angle        10075 non-null  float64
#  10  Neck_Angle              10075 non-null  float64
#  11  Left_Ankle_Angle        10075 non-null  float64
#  12  Right_Ankle_Angle       10075 non-null  float64
#  13  Left_Heel_Angle         10075 non-null  float64
#  14  Right_Heel_Angle        10075 non-null  float64
#  15  Left_Foot_Index_Angle   10075 non-null  float64
#  16  Right_Foot_Index_Angle  10075 non-null  float64
#  17  Label                   10075 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 1.4 MB
# None
# File in process : Copy of push up 37.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10141 entries, 0 to 10140
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     10141 non-null  float64
#  1   Right_Shoulder_Angle    10141 non-null  float64
#  2   Left_Elbow_Angle        10141 non-null  float64
#  3   Right_Elbow_Angle       10141 non-null  float64
#  4   Left_Wrist_Angle        10141 non-null  float64
#  5   Right_Wrist_Angle       10141 non-null  float64
#  6   Left_Hip_Angle          10141 non-null  float64
#  7   Right_Hip_Angle         10141 non-null  float64
#  8   Left_Knee_Angle         10141 non-null  float64
#  9   Right_Knee_Angle        10141 non-null  float64
#  10  Neck_Angle              10141 non-null  float64
#  11  Left_Ankle_Angle        10141 non-null  float64
#  12  Right_Ankle_Angle       10141 non-null  float64
#  13  Left_Heel_Angle         10141 non-null  float64
#  14  Right_Heel_Angle        10141 non-null  float64
#  15  Left_Foot_Index_Angle   10141 non-null  float64
#  16  Right_Foot_Index_Angle  10141 non-null  float64
#  17  Label                   10141 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 1.4 MB
# None
# File in process : Copy of push up 42.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10257 entries, 0 to 10256
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     10257 non-null  float64
#  1   Right_Shoulder_Angle    10257 non-null  float64
#  2   Left_Elbow_Angle        10257 non-null  float64
#  3   Right_Elbow_Angle       10257 non-null  float64
#  4   Left_Wrist_Angle        10257 non-null  float64
#  5   Right_Wrist_Angle       10257 non-null  float64
#  6   Left_Hip_Angle          10257 non-null  float64
#  7   Right_Hip_Angle         10257 non-null  float64
#  8   Left_Knee_Angle         10257 non-null  float64
#  9   Right_Knee_Angle        10257 non-null  float64
#  10  Neck_Angle              10257 non-null  float64
#  11  Left_Ankle_Angle        10257 non-null  float64
#  12  Right_Ankle_Angle       10257 non-null  float64
#  13  Left_Heel_Angle         10257 non-null  float64
#  14  Right_Heel_Angle        10257 non-null  float64
#  15  Left_Foot_Index_Angle   10257 non-null  float64
#  16  Right_Foot_Index_Angle  10257 non-null  float64
#  17  Label                   10257 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 1.4 MB
# None
# File in process : Copy of push up 44.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10356 entries, 0 to 10355
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     10356 non-null  float64
#  1   Right_Shoulder_Angle    10356 non-null  float64
#  2   Left_Elbow_Angle        10356 non-null  float64
#  3   Right_Elbow_Angle       10356 non-null  float64
#  4   Left_Wrist_Angle        10356 non-null  float64
#  5   Right_Wrist_Angle       10356 non-null  float64
#  6   Left_Hip_Angle          10356 non-null  float64
#  7   Right_Hip_Angle         10356 non-null  float64
#  8   Left_Knee_Angle         10356 non-null  float64
#  9   Right_Knee_Angle        10356 non-null  float64
#  10  Neck_Angle              10356 non-null  float64
#  11  Left_Ankle_Angle        10356 non-null  float64
#  12  Right_Ankle_Angle       10356 non-null  float64
#  13  Left_Heel_Angle         10356 non-null  float64
#  14  Right_Heel_Angle        10356 non-null  float64
#  15  Left_Foot_Index_Angle   10356 non-null  float64
#  16  Right_Foot_Index_Angle  10356 non-null  float64
#  17  Label                   10356 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 1.4 MB
# None
# File in process : Copy of push up 46.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10456 entries, 0 to 10455
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     10456 non-null  float64
#  1   Right_Shoulder_Angle    10456 non-null  float64
#  2   Left_Elbow_Angle        10456 non-null  float64
#  3   Right_Elbow_Angle       10456 non-null  float64
#  4   Left_Wrist_Angle        10456 non-null  float64
#  5   Right_Wrist_Angle       10456 non-null  float64
#  6   Left_Hip_Angle          10456 non-null  float64
#  7   Right_Hip_Angle         10456 non-null  float64
#  8   Left_Knee_Angle         10456 non-null  float64
#  9   Right_Knee_Angle        10456 non-null  float64
#  10  Neck_Angle              10456 non-null  float64
#  11  Left_Ankle_Angle        10456 non-null  float64
#  12  Right_Ankle_Angle       10456 non-null  float64
#  13  Left_Heel_Angle         10456 non-null  float64
#  14  Right_Heel_Angle        10456 non-null  float64
#  15  Left_Foot_Index_Angle   10456 non-null  float64
#  16  Right_Foot_Index_Angle  10456 non-null  float64
#  17  Label                   10456 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 1.4 MB
# None
# File in process : Copy of push up 55.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10569 entries, 0 to 10568
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     10569 non-null  float64
#  1   Right_Shoulder_Angle    10569 non-null  float64
#  2   Left_Elbow_Angle        10569 non-null  float64
#  3   Right_Elbow_Angle       10569 non-null  float64
#  4   Left_Wrist_Angle        10569 non-null  float64
#  5   Right_Wrist_Angle       10569 non-null  float64
#  6   Left_Hip_Angle          10569 non-null  float64
#  7   Right_Hip_Angle         10569 non-null  float64
#  8   Left_Knee_Angle         10569 non-null  float64
#  9   Right_Knee_Angle        10569 non-null  float64
#  10  Neck_Angle              10569 non-null  float64
#  11  Left_Ankle_Angle        10569 non-null  float64
#  12  Right_Ankle_Angle       10569 non-null  float64
#  13  Left_Heel_Angle         10569 non-null  float64
#  14  Right_Heel_Angle        10569 non-null  float64
#  15  Left_Foot_Index_Angle   10569 non-null  float64
#  16  Right_Foot_Index_Angle  10569 non-null  float64
#  17  Label                   10569 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 1.5 MB
# None
# File in process : Copy of push up 56.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10676 entries, 0 to 10675
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     10676 non-null  float64
#  1   Right_Shoulder_Angle    10676 non-null  float64
#  2   Left_Elbow_Angle        10676 non-null  float64
#  3   Right_Elbow_Angle       10676 non-null  float64
#  4   Left_Wrist_Angle        10676 non-null  float64
#  5   Right_Wrist_Angle       10676 non-null  float64
#  6   Left_Hip_Angle          10676 non-null  float64
#  7   Right_Hip_Angle         10676 non-null  float64
#  8   Left_Knee_Angle         10676 non-null  float64
#  9   Right_Knee_Angle        10676 non-null  float64
#  10  Neck_Angle              10676 non-null  float64
#  11  Left_Ankle_Angle        10676 non-null  float64
#  12  Right_Ankle_Angle       10676 non-null  float64
#  13  Left_Heel_Angle         10676 non-null  float64
#  14  Right_Heel_Angle        10676 non-null  float64
#  15  Left_Foot_Index_Angle   10676 non-null  float64
#  16  Right_Foot_Index_Angle  10676 non-null  float64
#  17  Label                   10676 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 1.5 MB
# None
# File in process : Copy of push up 57.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10751 entries, 0 to 10750
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     10751 non-null  float64
#  1   Right_Shoulder_Angle    10751 non-null  float64
#  2   Left_Elbow_Angle        10751 non-null  float64
#  3   Right_Elbow_Angle       10751 non-null  float64
#  4   Left_Wrist_Angle        10751 non-null  float64
#  5   Right_Wrist_Angle       10751 non-null  float64
#  6   Left_Hip_Angle          10751 non-null  float64
#  7   Right_Hip_Angle         10751 non-null  float64
#  8   Left_Knee_Angle         10751 non-null  float64
#  9   Right_Knee_Angle        10751 non-null  float64
#  10  Neck_Angle              10751 non-null  float64
#  11  Left_Ankle_Angle        10751 non-null  float64
#  12  Right_Ankle_Angle       10751 non-null  float64
#  13  Left_Heel_Angle         10751 non-null  float64
#  14  Right_Heel_Angle        10751 non-null  float64
#  15  Left_Foot_Index_Angle   10751 non-null  float64
#  16  Right_Foot_Index_Angle  10751 non-null  float64
#  17  Label                   10751 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 1.5 MB
# None
# File in process : Copy of push up 58.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10835 entries, 0 to 10834
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     10835 non-null  float64
#  1   Right_Shoulder_Angle    10835 non-null  float64
#  2   Left_Elbow_Angle        10835 non-null  float64
#  3   Right_Elbow_Angle       10835 non-null  float64
#  4   Left_Wrist_Angle        10835 non-null  float64
#  5   Right_Wrist_Angle       10835 non-null  float64
#  6   Left_Hip_Angle          10835 non-null  float64
#  7   Right_Hip_Angle         10835 non-null  float64
#  8   Left_Knee_Angle         10835 non-null  float64
#  9   Right_Knee_Angle        10835 non-null  float64
#  10  Neck_Angle              10835 non-null  float64
#  11  Left_Ankle_Angle        10835 non-null  float64
#  12  Right_Ankle_Angle       10835 non-null  float64
#  13  Left_Heel_Angle         10835 non-null  float64
#  14  Right_Heel_Angle        10835 non-null  float64
#  15  Left_Foot_Index_Angle   10835 non-null  float64
#  16  Right_Foot_Index_Angle  10835 non-null  float64
#  17  Label                   10835 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 1.5 MB
# None
# File in process : Copy of push up 81.mp4
# Label: False
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10928 entries, 0 to 10927
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Left_Shoulder_Angle     10928 non-null  float64
#  1   Right_Shoulder_Angle    10928 non-null  float64
#  2   Left_Elbow_Angle        10928 non-null  float64
#  3   Right_Elbow_Angle       10928 non-null  float64
#  4   Left_Wrist_Angle        10928 non-null  float64
#  5   Right_Wrist_Angle       10928 non-null  float64
#  6   Left_Hip_Angle          10928 non-null  float64
#  7   Right_Hip_Angle         10928 non-null  float64
#  8   Left_Knee_Angle         10928 non-null  float64
#  9   Right_Knee_Angle        10928 non-null  float64
#  10  Neck_Angle              10928 non-null  float64
#  11  Left_Ankle_Angle        10928 non-null  float64
#  12  Right_Ankle_Angle       10928 non-null  float64
#  13  Left_Heel_Angle         10928 non-null  float64
#  14  Right_Heel_Angle        10928 non-null  float64
#  15  Left_Foot_Index_Angle   10928 non-null  float64
#  16  Right_Foot_Index_Angle  10928 non-null  float64
#  17  Label                   10928 non-null  int64
# dtypes: float64(17), int64(1)
# memory usage: 1.5 MB
# None
# Data saved to Datasets/label.csv
