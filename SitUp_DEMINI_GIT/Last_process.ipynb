# %% [markdown]
# Load Datasets

# %%
import pandas as pd

# Load the datasets
df1 = pd.read_csv(r'D:\DESKTOP\DSGP -Main\DSGP-Group28\SitUp_DEMINI_GIT\Dataset\Processed_Dataset.csv')
df2 = pd.read_csv(r'D:\DESKTOP\DSGP -Main\DSGP-Group28\SitUp_DEMINI_GIT\New Data\Processed_Dataset(PULL).csv')
df3 = pd.read_csv(r'D:\DESKTOP\DSGP -Main\DSGP-Group28\SitUp_DEMINI_GIT\New Data\Processed_Dataset(SQ).csv')
df4 = pd.read_csv(r'D:\DESKTOP\DSGP -Main\DSGP-Group28\SitUp_DEMINI_GIT\New Data\Processed_Dataset(MC).csv')


# Concatenate the datasets vertically
df = pd.concat([df1, df2, df3,df4], axis=0, ignore_index=True)

# %% [markdown]
# check Duplicates and Missing

# %%
# Check for duplicates
duplicates = df.duplicated().sum()
if duplicates:
    print(f"There are {duplicates} duplicate rows in the Dataset.")
else:
    print("There are no duplicate rows in the Dataset.")

# Check for missing values
missing_values = df.isnull().sum().sum()
if missing_values:
    print(f"There are {missing_values} missing values in the Dataset.")
else:
    print("There are no missing values in the Dataset.")
# Out:
# There are no duplicate rows in the Dataset.
# There are no missing values in the Dataset.

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Left_Shoulder_Angle       0
# Right_Shoulder_Angle      0
# Left_Elbow_Angle          0
# Right_Elbow_Angle         0
# Left_Wrist_Angle          0
# Right_Wrist_Angle         0
# Left_Hip_Angle            0
# Right_Hip_Angle           0
# Left_Knee_Angle           0
# Right_Knee_Angle          0
# Neck_Angle                0
# Left_Ankle_Angle          0
# Right_Ankle_Angle         0
# Left_Heel_Angle           0
# Right_Heel_Angle          0
# Left_Foot_Index_Angle     0
# Right_Foot_Index_Angle    0
# Label                     0
# dtype: int64

# %%
df
# Out:
#       Left_Shoulder_Angle  Right_Shoulder_Angle  Left_Elbow_Angle  \
# 0               86.886181            102.217050        290.080625
# 1               69.200225            101.286537         97.392171
# 2               70.441044            100.931392        295.872597
# 3               57.921893            100.558760        110.444084
# 4               62.469626            100.866528        299.662393
# ...                   ...                   ...               ...
# 7239           103.906037            105.037830        205.088009
# 7240           103.273505            105.169216        206.656170
# 7241           102.926432            105.305722        207.615836
# 7242           102.880942            105.364070        207.929991
# 7243           103.163199            105.620306        207.900556
#
#       Right_Elbow_Angle  Left_Wrist_Angle  Right_Wrist_Angle  Left_Hip_Angle  \
# 0            302.234731         46.325401          60.057965       20.626466
# 1            302.083759        302.337262          61.144008       21.459244
# 2            302.383273         58.331556          61.711901       21.973149
# 3            302.401433        298.913412          61.485727       21.901033
# 4            301.771460         45.428596          60.955503       21.753383
# ...                 ...               ...                ...             ...
# 7239         199.873616         14.160873           9.824494      152.519471
# 7240         199.851937         14.962760           9.803539      152.157762
# 7241         199.819019         15.447437           9.785858      151.952588
# 7242         199.869300         15.629897           9.811188      151.880952
# 7243         199.728203         15.627830           9.750330      151.879213
#
#       Right_Hip_Angle  Left_Knee_Angle  Right_Knee_Angle  Neck_Angle  \
# 0           22.178229       328.564964        326.460169  345.672500
# 1           22.902328       326.949727        326.684704  345.603097
# 2           23.366246       326.581833        327.028278  346.096492
# 3           23.591118       326.700021        326.976787  344.806734
# 4           23.817633       326.776260        327.004609  344.236505
# ...               ...              ...               ...         ...
# 7239       155.114205        56.447203         54.424563  357.790170
# 7240       154.795660        54.878124         55.526886  357.649451
# 7241       154.455742        54.659095         56.907112  357.570033
# 7242       154.290290        56.503861         57.846396  357.638088
# 7243       154.098712        57.627823         58.925351  357.889216
#
#       Left_Ankle_Angle  Right_Ankle_Angle  Left_Heel_Angle  Right_Heel_Angle  \
# 0           200.797268         211.920729        38.887251         45.163103
# 1           205.004343         212.324104        42.762729         50.629030
# 2           206.328984         211.966704        51.014744         56.300034
# 3           207.628487         212.489967        55.413270         60.124014
# 4           206.325982         211.986013        57.076447         59.053438
# ...                ...                ...              ...               ...
# 7239        145.423387         139.673141       329.312470        317.336195
# 7240        147.099901         138.595134       328.929514        317.458213
# 7241        147.490134         137.182877       329.197396        317.169724
# 7242        146.064462         136.405674       329.979285        317.366293
# 7243        144.980397         135.043206       330.334291        317.758452
#
#       Left_Foot_Index_Angle  Right_Foot_Index_Angle  Label
# 0                309.835865              318.866848      1
# 1                306.787815              318.245993      1
# 2                307.380023              318.340008      1
# 3                308.089960              318.254115      1
# 4                308.626997              318.134012      1
# ...                     ...                     ...    ...
# 7239              76.573635               46.646948      0
# 7240              78.807252               46.669791      0
# 7241              78.375090               46.357422      0
# 7242              76.263321               46.002077      0
# 7243              74.504541               45.483266      0
#
# [7244 rows x 18 columns]

# %% [markdown]
# Remove Outliers

# %%
import pandas as pd
import numpy as np

# Function to remove outliers based on IQR method
def remove_outliers(df):
    cleaned_df = df.copy()
    for col in df.columns:
        if df[col].dtype in ['int64', 'float64']:
            q1 = df[col].quantile(0.25)
            q3 = df[col].quantile(0.75)
            iqr = q3 - q1
            lower_bound = q1 - 1.5 * iqr
            upper_bound = q3 + 1.5 * iqr
            cleaned_df = cleaned_df[(cleaned_df[col] >= lower_bound) & (cleaned_df[col] <= upper_bound)]
    return cleaned_df

# Check outliers
outliers_removed_df = remove_outliers(df)

# Display the shape of the original and cleaned DataFrame
print("Original DataFrame shape:", df.shape)
print("DataFrame shape after removing outliers:", outliers_removed_df.shape)

# Display the cleaned DataFrame
print(outliers_removed_df)
# Out:
# Original DataFrame shape: (7244, 18)
# DataFrame shape after removing outliers: (6740, 18)
#       Left_Shoulder_Angle  Right_Shoulder_Angle  Left_Elbow_Angle  \
# 0               86.886181            102.217050        290.080625
# 1               69.200225            101.286537         97.392171
# 2               70.441044            100.931392        295.872597
# 3               57.921893            100.558760        110.444084
# 4               62.469626            100.866528        299.662393
# ...                   ...                   ...               ...
# 7239           103.906037            105.037830        205.088009
# 7240           103.273505            105.169216        206.656170
# 7241           102.926432            105.305722        207.615836
# 7242           102.880942            105.364070        207.929991
# 7243           103.163199            105.620306        207.900556
#
#       Right_Elbow_Angle  Left_Wrist_Angle  Right_Wrist_Angle  Left_Hip_Angle  \
# 0            302.234731         46.325401          60.057965       20.626466
# 1            302.083759        302.337262          61.144008       21.459244
# 2            302.383273         58.331556          61.711901       21.973149
# 3            302.401433        298.913412          61.485727       21.901033
# 4            301.771460         45.428596          60.955503       21.753383
# ...                 ...               ...                ...             ...
# 7239         199.873616         14.160873           9.824494      152.519471
# 7240         199.851937         14.962760           9.803539      152.157762
# 7241         199.819019         15.447437           9.785858      151.952588
# 7242         199.869300         15.629897           9.811188      151.880952
# 7243         199.728203         15.627830           9.750330      151.879213
#
#       Right_Hip_Angle  Left_Knee_Angle  Right_Knee_Angle  Neck_Angle  \
# 0           22.178229       328.564964        326.460169  345.672500
# 1           22.902328       326.949727        326.684704  345.603097
# 2           23.366246       326.581833        327.028278  346.096492
# 3           23.591118       326.700021        326.976787  344.806734
# 4           23.817633       326.776260        327.004609  344.236505
# ...               ...              ...               ...         ...
# 7239       155.114205        56.447203         54.424563  357.790170
# 7240       154.795660        54.878124         55.526886  357.649451
# 7241       154.455742        54.659095         56.907112  357.570033
# 7242       154.290290        56.503861         57.846396  357.638088
# 7243       154.098712        57.627823         58.925351  357.889216
#
#       Left_Ankle_Angle  Right_Ankle_Angle  Left_Heel_Angle  Right_Heel_Angle  \
# 0           200.797268         211.920729        38.887251         45.163103
# 1           205.004343         212.324104        42.762729         50.629030
# 2           206.328984         211.966704        51.014744         56.300034
# 3           207.628487         212.489967        55.413270         60.124014
# 4           206.325982         211.986013        57.076447         59.053438
# ...                ...                ...              ...               ...
# 7239        145.423387         139.673141       329.312470        317.336195
# 7240        147.099901         138.595134       328.929514        317.458213
# 7241        147.490134         137.182877       329.197396        317.169724
# 7242        146.064462         136.405674       329.979285        317.366293
# 7243        144.980397         135.043206       330.334291        317.758452
#
#       Left_Foot_Index_Angle  Right_Foot_Index_Angle  Label
# 0                309.835865              318.866848      1
# 1                306.787815              318.245993      1
# 2                307.380023              318.340008      1
# 3                308.089960              318.254115      1
# 4                308.626997              318.134012      1
# ...                     ...                     ...    ...
# 7239              76.573635               46.646948      0
# 7240              78.807252               46.669791      0
# 7241              78.375090               46.357422      0
# 7242              76.263321               46.002077      0
# 7243              74.504541               45.483266      0
#
# [6740 rows x 18 columns]

# %% [markdown]
# Balance Dataset

# %%
from imblearn.over_sampling import SMOTE

# Separate features (X) and labels (y)
X = outliers_removed_df.drop(['Label'], axis=1)
y = outliers_removed_df['Label']

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Apply SMOTE to the dataset
X_balanced, y_balanced = smote.fit_resample(X, y)

# Create a balanced DataFrame
balanced_df = pd.concat([pd.DataFrame(X_balanced, columns=X.columns), pd.Series(y_balanced, name='Label')], axis=1)

# Display the shape of the balanced DataFrame
print("Balanced DataFrame shape:", balanced_df.shape)

# Display the class distribution in the balanced DataFrame
print("Class distribution in balanced DataFrame:")
print(balanced_df['Label'].value_counts())
# Out:
# Balanced DataFrame shape: (7202, 18)
# Class distribution in balanced DataFrame:
# Label
# 1    3601
# 0    3601
# Name: count, dtype: int64

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# Separate features (X) and labels (y)
X = balanced_df.drop(['Label'], axis=1)
y = balanced_df['Label']

# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform the features, excluding the 'Label' column
X_scaled = scaler.fit_transform(X)

# Create a DataFrame with scaled features and the 'Label' column
scaled_df = pd.concat([pd.DataFrame(X_scaled, columns=X.columns), pd.Series(y, name='Label')], axis=1)

# Display the first few rows of the scaled DataFrame
print("Scaled DataFrame:")
print(scaled_df.head())
# Out:
# Scaled DataFrame:
#    Left_Shoulder_Angle  Right_Shoulder_Angle  Left_Elbow_Angle  \
# 0            -0.765869             -0.771899          0.934720
# 1            -0.959683             -0.781937         -1.590338
# 2            -0.946085             -0.785768          1.010620
# 3            -1.083278             -0.789788         -1.419301
# 4            -1.033441             -0.786468          1.060283
#
#    Right_Elbow_Angle  Left_Wrist_Angle  Right_Wrist_Angle  Left_Hip_Angle  \
# 0           1.102797         -0.645596          -0.815366       -1.913271
# 1           1.101149          1.145776          -0.807800       -1.902165
# 2           1.104418         -0.561587          -0.803844       -1.895311
# 3           1.104616          1.121818          -0.805419       -1.896273
# 4           1.097740         -0.651872          -0.809113       -1.898242
#
#    Right_Hip_Angle  Left_Knee_Angle  Right_Knee_Angle  Neck_Angle  \
# 0        -1.814985         1.475898          1.393425    1.268194
# 1        -1.805792         1.456733          1.395941    1.267726
# 2        -1.799903         1.452368          1.399792    1.271054
# 3        -1.797048         1.453771          1.399215    1.262354
# 4        -1.794173         1.454675          1.399527    1.258508
#
#    Left_Ankle_Angle  Right_Ankle_Angle  Left_Heel_Angle  Right_Heel_Angle  \
# 0          0.491259           0.774887        -1.182661         -1.032209
# 1          0.602484           0.784933        -1.148027         -0.985365
# 2          0.637504           0.776032        -1.074279         -0.936762
# 3          0.671859           0.789064        -1.034970         -0.903989
# 4          0.637424           0.776513        -1.020106         -0.913165
#
#    Left_Foot_Index_Angle  Right_Foot_Index_Angle  Label
# 0               0.740840                0.865444      1
# 1               0.721189                0.861507      1
# 2               0.725007                0.862103      1
# 3               0.729584                0.861559      1
# 4               0.733046                0.860797      1

# %% [markdown]
# Save Data

# %%
# Save the scaled DataFrame as CSV
scaled_df.to_csv('Dataset/New_Final_Dataset.csv', index=False)
